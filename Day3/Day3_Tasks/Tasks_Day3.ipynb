# %% [markdown]
# # Saurabh Kumar | ESET0128  |   Advance Python AIML DAY:3

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 1. Load the Titanic dataset and perform univariate and bivariate analysis on numerical and categorical features.

# %%
import seaborn as sns
data=sns.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
# Descriptive analysis
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# Statistical Anlaysis
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Finding unique value in each column
data.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
# Finding null values in each column
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# Bivariate Analysis
s=data.groupby('survived')['age'].mean()
s
# Out:
# survived
# 0    30.626179
# 1    28.343690
# Name: age, dtype: float64

# %%
# Insigths on survival
sns.countplot(x='survived',data=data)
plt.show()

# %%
# Passanger age insight
sns.histplot(data['age'], bins=50)
plt.show()

# %%
# Seperating numerical and non-numeric columns
num_col=data.select_dtypes(include=['int64','float64'])
obj_col=data.select_dtypes(exclude=['int64','float64'])

# %%
num_col
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
obj_col
# Out:
#         sex embarked   class    who  adult_male deck  embark_town alive  alone
# 0      male        S   Third    man        True  NaN  Southampton    no  False
# 1    female        C   First  woman       False    C    Cherbourg   yes  False
# 2    female        S   Third  woman       False  NaN  Southampton   yes   True
# 3    female        S   First  woman       False    C  Southampton   yes  False
# 4      male        S   Third    man        True  NaN  Southampton    no   True
# ..      ...      ...     ...    ...         ...  ...          ...   ...    ...
# 886    male        S  Second    man        True  NaN  Southampton    no   True
# 887  female        S   First  woman       False    B  Southampton   yes   True
# 888  female        S   Third  woman       False  NaN  Southampton    no  False
# 889    male        C   First    man        True    C    Cherbourg   yes   True
# 890    male        Q   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 9 columns]

# %%
sns.countplot(x='survived',data=num_col['age'])
plt.show()

# %%
# Insight of which sex got survived or not.
sns.histplot(data=data, x='sex',hue='survived')
plt.show()

# %%
# Insight of which age person got survived or not.
sns.histplot(data=data, x='age',hue='survived',bins=50)
plt.show()

# %% [markdown]
# ### 2. Identify and visualize outliers using boxplots.

# %%
import matplotlib.pyplot as plt

# Using boxplot to detect Outlier 
Sample_data = [10,12,11,13,100,12,11,13] 
plt.boxplot(Sample_data)
plt.show()

# %% [markdown]
# ### 3. Display the correlation matrix and visually interpret relationships using seaborn.heatmap().

# %%
# Take 'iris' dataset as sample [load_dataset('iris')]
data_iris=sns.load_dataset('iris')
type(data_iris)
data_iris.select_dtypes(exclude='object').corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(data_iris.select_dtypes(exclude='object').corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### 4. Compute and interpret mean, median, mode, variance, and standard deviation for a given dataset.

# %%
import statistics
num_col_iris=data_iris.select_dtypes(exclude='object')
num_col_iris
print("\nColumn wise MEAN value:\n",num_col_iris.mean(axis=0))
print("\nColumn wise MEDIAN value:\n",num_col_iris.median(axis=0))
print("\nColumn wise MOD value:\n",num_col_iris.mode(axis=0))
print("\nColumn wise VARIANCE value:\n",num_col_iris.var(axis=0))
print("\nColumn wise STANDERED DEVIATION value:\n",num_col_iris.std(axis=0))
# Out:
# Column wise MEAN value:
#  sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64
#
# Column wise MEDIAN value:
#  sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64
#
# Column wise MOD value:
#     sepal_length  sepal_width  petal_length  petal_width
# 0           5.0          3.0           1.4          0.2
# 1           NaN          NaN           1.5          NaN
#
# Column wise VARIANCE value:
#  sepal_length    0.685694
# sepal_width     0.189979
# petal_length    3.116278
# petal_width     0.581006
# dtype: float64
#
# Column wise STANDERED DEVIATION value:
#  sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# dtype: float64

# %% [markdown]
# ### 5. Load a dataset with missing values. Demonstrate imputation using mean, median, and mode techniques.

# %%
car_data=pd.read_csv('car1.csv')
car_data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
car_data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
# Data Imputation
car_data['Engine Fuel Type']=car_data.groupby('Model')['Engine Fuel Type'].transform(lambda x:x.fillna(x.mode().iloc[0] if not x.mode().empty else None))
car_data['Number of Doors'] = car_data.groupby('Model')['Number of Doors'].transform(lambda x: x.fillna(x.mean()))
car_data['Engine Cylinders'] = car_data.groupby('Make')['Engine Cylinders'].transform(lambda x: x.fillna(x.median()))
car_data['Engine HP'] = car_data.groupby('Model')['Engine HP'].transform(lambda x: x.fillna(x.mode()))

# %%
car_data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP              69
# Engine Cylinders        0
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         0
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# ### 6. Write a custom function that removes rows where more than 30% of data is missing.

# %%
# Function to remove the row, where more than 30 percent of data in column is missing
def remove_row(p):
    for item in range(0,len(p)+1):
        per=(p.loc[item].isnull().sum())/len(p.loc[item])    
        if per >= 0.3:
            p=p.drop(p.index[item])

        return p

# %%
## Sample Data {'A':[1,None,3], 'B':[None,None,2], 'C':[1,2,None]}
## Row no. B will be dropped in this case.
d=pd.DataFrame([[1,3,None],[4,None,None],[None,9, 10],[7,9,33],[8,45,23]],columns=['A','B','C'])
d
# Out:
#      A     B     C
# 0  1.0   3.0   NaN
# 1  4.0   NaN   NaN
# 2  NaN   9.0  10.0
# 3  7.0   9.0  33.0
# 4  8.0  45.0  23.0

# %%
remove_row(d)
# Out:
#      A     B     C
# 2  NaN   9.0  10.0
# 3  7.0   9.0  33.0
# 4  8.0  45.0  23.0
