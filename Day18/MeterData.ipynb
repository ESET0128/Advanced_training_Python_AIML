# %% [markdown]
# # Saurabh Kumar | ESET0128  |   Advance Python AIML DAY:18

# %% [markdown]
# ## Analysis on smart meter data

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/smart_meter_data.csv')

# %%
df.head()
# Out:
#               datetime       msn location  daily_consumption_load  \
# 0  2021-01-01 00:00:00  ACE43B7D  Chennai                    2.59
# 1  2021-01-01 00:15:00  ACE43B7D  Chennai                    1.78
# 2  2021-01-01 00:30:00  ACE43B7D  Chennai                    2.59
# 3  2021-01-01 00:45:00  ACE43B7D  Chennai                    2.45
# 4  2021-01-01 01:00:00  ACE43B7D  Chennai                    1.48
#
#    energy_supplied  energy_billed
# 0             2.78           2.57
# 1             2.12           1.86
# 2             2.68           2.52
# 3             2.56           2.50
# 4             1.56           1.49

# %%
d1=df[df['location'].isin(['Chennai'])]
display(d1.head())
# Out:
#               datetime       msn location  daily_consumption_load  \
# 0  2021-01-01 00:00:00  ACE43B7D  Chennai                    2.59
# 1  2021-01-01 00:15:00  ACE43B7D  Chennai                    1.78
# 2  2021-01-01 00:30:00  ACE43B7D  Chennai                    2.59
# 3  2021-01-01 00:45:00  ACE43B7D  Chennai                    2.45
# 4  2021-01-01 01:00:00  ACE43B7D  Chennai                    1.48
#
#    energy_supplied  energy_billed
# 0             2.78           2.57
# 1             2.12           1.86
# 2             2.68           2.52
# 3             2.56           2.50
# 4             1.56           1.49

# %%
d1['msn'].unique()
# Out:
# array(['ACE43B7D'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.plot(d1['daily_consumption_load'])

# %%
loction=['Mumbai','Chennai','Kolkata','Bengaluru','Delhi']
for item in loction:
  d2=df[df['location'].isin([item])]
  plt.figure()
  plt.plot(d2['daily_consumption_load'])


# d2=df[df['location'].isin(['Mumbai'])]
# display(d2.head())
# d1['msn'].unique()
# Out:
#                    datetime       msn location  daily_consumption_load  \
# 420480  2021-01-01 00:00:00  3F42A75F   Mumbai                    4.83
# 420481  2021-01-01 00:15:00  3F42A75F   Mumbai                    1.13
# 420482  2021-01-01 00:30:00  3F42A75F   Mumbai                    1.58
# 420483  2021-01-01 00:45:00  3F42A75F   Mumbai                    0.93
# 420484  2021-01-01 01:00:00  3F42A75F   Mumbai                    0.64
#
#         energy_supplied  energy_billed
# 420480             4.82           4.81
# 420481             1.15           1.10
# 420482             1.79           1.53
# 420483             0.97           0.95
# 420484             0.76           0.65
#               datetime       msn location  daily_consumption_load  \
# 0  2021-01-01 00:00:00  ACE43B7D  Chennai                    2.59
# 1  2021-01-01 00:15:00  ACE43B7D  Chennai                    1.78
# 2  2021-01-01 00:30:00  ACE43B7D  Chennai                    2.59
# ...
